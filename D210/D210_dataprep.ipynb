# %% [markdown]
# # D210 Data Preparation
#
# ### Data import

# %%
import pandas as pd
import numpy as np

# Read our hospital data CSV, keep only CaseOrder, State, Children, Age, Income, Marital, Gender, ReAdmis, VitD_level
med = pd.read_csv('medical_clean.csv', usecols=['CaseOrder', 'State', 'Children', 'Age', 'Income', 'Marital', 'Gender', 'ReAdmis', 'VitD_levels'])

# Read CMS Hospital Readmissions data, keep Facility ID, State, Readmission Measure, Readmission Rate
hosp = pd.read_csv('FY_2023_Hospital_Readmissions_Reduction_Program_Hospital.csv', usecols=[1,2,3,7])

# Read NHANES 2017-18 Vit D Study data, keep sequence number (name as 'CaseOrder'), Vit D blood serum level
vitd = pd.read_csv('VitD.csv', header=0, names=['CaseOrder', 'Vitamin D blood level (nmol/L)'], usecols=[0,1], na_values=['0'])

# Read NHANES 2017-18 Demographic data, keep sequence number (name as 'CaseOrder'), Gender, Age, Marital, Children (2 columns will need to be combined), Income
vitd_demo = pd.read_csv('VitD_demog.csv', usecols=[0,3,4,17,31,32,44])

print(med.info())
print(hosp.info())
print(vitd.info())
print(vitd_demo.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CaseOrder    10000 non-null  int64
#  1   State        10000 non-null  object
#  2   Children     10000 non-null  int64
#  3   Age          10000 non-null  int64
#  4   Income       10000 non-null  float64
#  5   Marital      10000 non-null  object
#  6   Gender       10000 non-null  object
#  7   ReAdmis      10000 non-null  object
#  8   VitD_levels  10000 non-null  float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 703.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18990 entries, 0 to 18989
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Facility ID                 18990 non-null  int64
#  1   State                       18990 non-null  object
#  2   Measure Name                18990 non-null  object
#  3   Predicted Readmission Rate  12919 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 593.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8400 entries, 0 to 8399
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CaseOrder                       8366 non-null   float64
#  1   Vitamin D blood level (nmol/L)  7409 non-null   float64
# dtypes: float64(2)
# memory usage: 131.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9254 non-null   float64
#  1   RIAGENDR  9254 non-null   float64
#  2   RIDAGEYR  9254 non-null   float64
#  3   DMDMARTL  9254 non-null   float64
#  4   DMDHHSZA  9254 non-null   float64
#  5   DMDHHSZB  9254 non-null   float64
#  6   INDFMIN2  9254 non-null   float64
# dtypes: float64(7)
# memory usage: 508.7 KB
# None

# %%
# Drop rows with null data & convert data types
med=med.dropna().convert_dtypes()
hosp=hosp.dropna().convert_dtypes()
vitd=vitd.dropna().convert_dtypes()
# Will convert dtypes manually in order to decode later
vitd_demo=vitd_demo.dropna()
vitd_demo=vitd_demo.astype({'SEQN': int, 'RIAGENDR': int, 'RIDAGEYR': int, 'DMDMARTL': int, 'DMDHHSZA':int, 'DMDHHSZB':int, 'INDFMIN2':int})

# %%
print(vitd_demo.info())
vitd_demo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9254 entries, 0 to 9253
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9254 non-null   int32
#  1   RIAGENDR  9254 non-null   int32
#  2   RIDAGEYR  9254 non-null   int32
#  3   DMDMARTL  9254 non-null   int32
#  4   DMDHHSZA  9254 non-null   int32
#  5   DMDHHSZB  9254 non-null   int32
#  6   INDFMIN2  9254 non-null   int32
# dtypes: int32(7)
# memory usage: 325.3 KB
# None
#     SEQN  RIAGENDR  RIDAGEYR  DMDMARTL  DMDHHSZA  DMDHHSZB  INDFMIN2
# 0  93703         2         2         0         3         0        15
# 1  93704         1         2         0         2         0        15
# 2  93705         2        66         3         0         0         3
# 3  93706         1        18         0         0         0         0
# 4  93707         1        13         0         0         3        10

# %% [markdown]
# #### Re-express coded variables categorically
# Based on data dictionary at https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.htm

# %%
dict_gender = {1: 'Male', 2: 'Female'}
  
dict_marital = {0: np.nan, 1: 'Married', 2: 'Widowed', 3: 'Divorced', 4: 'Separated', 5: 'Never Married', 6: np.nan, 77: np.nan}

# NHANES uses codes for ranges of incomes - set to midpoint of range
dict_inc = {0: np.nan, 1: 2500, 2: 7500, 3: 12500, 4: 17500, 5: 22500, 6: 30000, 7: 40000, 8: 50000, 9: 60000, 10: 70000, 12: 35000, 13: 10000, 14: 87500, 15: 150000, 77: np.nan, 99: np.nan}

replace_dict = {'RIAGENDR': dict_gender, 'DMDMARTL': dict_marital, 'INDFMIN2': dict_inc}
vitd_demo.replace(replace_dict, inplace=True)

# %%
vitd_demo.head(20)
# Out:
#      SEQN RIAGENDR  RIDAGEYR       DMDMARTL  DMDHHSZA  DMDHHSZB  INDFMIN2
# 0   93703   Female         2            NaN         3         0  150000.0
# 1   93704     Male         2            NaN         2         0  150000.0
# 2   93705   Female        66       Divorced         0         0   12500.0
# 3   93706     Male        18            NaN         0         0       NaN
# 4   93707     Male        13            NaN         0         3   70000.0
# 5   93708   Female        66        Married         0         0   30000.0
# 6   93709   Female        75        Widowed         0         0    7500.0
# 7   93710   Female         0            NaN         1         0  150000.0
# 8   93711     Male        56        Married         0         0  150000.0
# 9   93712     Male        18            NaN         0         2   17500.0
# 10  93713     Male        67       Divorced         0         0   30000.0
# 11  93714   Female        54        Married         0         1   40000.0
# 12  93715     Male        71        Married         1         2   50000.0
# 13  93716     Male        61        Married         0         0  150000.0
# 14  93717     Male        22  Never Married         0         0   17500.0
# 15  93718     Male        45  Never Married         3         1   70000.0
# 16  93719   Female        13            NaN         0         2   87500.0
# 17  93720   Female         1            NaN         1         0   87500.0
# 18  93721   Female        60        Married         0         0   50000.0
# 19  93722   Female        60       Divorced         0         0   30000.0

# %%
vitd_demo.rename(columns={'SEQN': 'CaseOrder', 'RIAGENDR': 'Gender', 'RIDAGEYR': 'Age', 'DMDMARTL': 'Marital', 'DMDHHSZA':'Children_under6', 'DMDHHSZB':'Children_6over', 'INDFMIN2':'Income'}, inplace=True)
vitd_demo.head()
# Out:
#    CaseOrder  Gender  Age   Marital  Children_under6  Children_6over    Income
# 0      93703  Female    2       NaN                3               0  150000.0
# 1      93704    Male    2       NaN                2               0  150000.0
# 2      93705  Female   66  Divorced                0               0   12500.0
# 3      93706    Male   18       NaN                0               0       NaN
# 4      93707    Male   13       NaN                0               3   70000.0

# %%
vitd_demo['Children'] = vitd_demo.Children_under6 + vitd_demo.Children_6over
vitd_demo.head(20)
# Out:
#     CaseOrder  Gender  Age        Marital  Children_under6  Children_6over  \
# 0       93703  Female    2            NaN                3               0
# 1       93704    Male    2            NaN                2               0
# 2       93705  Female   66       Divorced                0               0
# 3       93706    Male   18            NaN                0               0
# 4       93707    Male   13            NaN                0               3
# 5       93708  Female   66        Married                0               0
# 6       93709  Female   75        Widowed                0               0
# 7       93710  Female    0            NaN                1               0
# 8       93711    Male   56        Married                0               0
# 9       93712    Male   18            NaN                0               2
# 10      93713    Male   67       Divorced                0               0
# 11      93714  Female   54        Married                0               1
# 12      93715    Male   71        Married                1               2
# 13      93716    Male   61        Married                0               0
# 14      93717    Male   22  Never Married                0               0
# 15      93718    Male   45  Never Married                3               1
# 16      93719  Female   13            NaN                0               2
# 17      93720  Female    1            NaN                1               0
# 18      93721  Female   60        Married                0               0
# 19      93722  Female   60       Divorced                0               0
#
#       Income  Children
# 0   150000.0         3
# 1   150000.0         2
# 2    12500.0         0
# 3        NaN         0
# 4    70000.0         3
# 5    30000.0         0
# 6     7500.0         0
# 7   150000.0         1
# 8   150000.0         0
# 9    17500.0         2
# 10   30000.0         0
# 11   40000.0         1
# 12   50000.0         3
# 13  150000.0         0
# 14   17500.0         0
# 15   70000.0         4
# 16   87500.0         2
# 17   87500.0         1
# 18   50000.0         0
# 19   30000.0         0

# %%
vitd_demo.drop(axis=1, columns=['Children_under6', 'Children_6over'], inplace=True)

# %%
vitd_demo.head(20)
# Out:
#     CaseOrder  Gender  Age        Marital    Income  Children
# 0       93703  Female    2            NaN  150000.0         3
# 1       93704    Male    2            NaN  150000.0         2
# 2       93705  Female   66       Divorced   12500.0         0
# 3       93706    Male   18            NaN       NaN         0
# 4       93707    Male   13            NaN   70000.0         3
# 5       93708  Female   66        Married   30000.0         0
# 6       93709  Female   75        Widowed    7500.0         0
# 7       93710  Female    0            NaN  150000.0         1
# 8       93711    Male   56        Married  150000.0         0
# 9       93712    Male   18            NaN   17500.0         2
# 10      93713    Male   67       Divorced   30000.0         0
# 11      93714  Female   54        Married   40000.0         1
# 12      93715    Male   71        Married   50000.0         3
# 13      93716    Male   61        Married  150000.0         0
# 14      93717    Male   22  Never Married   17500.0         0
# 15      93718    Male   45  Never Married   70000.0         4
# 16      93719  Female   13            NaN   87500.0         2
# 17      93720  Female    1            NaN   87500.0         1
# 18      93721  Female   60        Married   50000.0         0
# 19      93722  Female   60       Divorced   30000.0         0

# %%
nhanes = vitd.merge(vitd_demo, how='left', on='CaseOrder', sort=True)
nhanes.head(20)
# Out:
#     CaseOrder  Vitamin D blood level (nmol/L)  Gender  Age        Marital  \
# 0       93704                            74.4    Male    2            NaN
# 1       93705                            89.9  Female   66       Divorced
# 2       93706                            53.8    Male   18            NaN
# 3       93707                            58.2    Male   13            NaN
# 4       93708                           116.0  Female   66        Married
# 5       93709                            72.8  Female   75        Widowed
# 6       93711                           165.0    Male   56        Married
# 7       93712                            59.9    Male   18            NaN
# 8       93713                            63.5    Male   67       Divorced
# 9       93714                            47.5  Female   54        Married
# 10      93715                            70.6    Male   71        Married
# 11      93716                            96.2    Male   61        Married
# 12      93717                            54.2    Male   22  Never Married
# 13      93718                            76.4    Male   45  Never Married
# 14      93719                            77.1  Female   13            NaN
# 15      93720                            62.7  Female    1            NaN
# 16      93721                            90.2  Female   60        Married
# 17      93722                            58.4  Female   60       Divorced
# 18      93723                           131.0    Male   64        Married
# 19      93724                            46.2  Female    5            NaN
#
#       Income  Children
# 0   150000.0         2
# 1    12500.0         0
# 2        NaN         0
# 3    70000.0         3
# 4    30000.0         0
# 5     7500.0         0
# 6   150000.0         0
# 7    17500.0         2
# 8    30000.0         0
# 9    40000.0         1
# 10   50000.0         3
# 11  150000.0         0
# 12   17500.0         0
# 13   70000.0         4
# 14   87500.0         2
# 15   87500.0         1
# 16   50000.0         0
# 17   30000.0         0
# 18   60000.0         0
# 19   17500.0         5

# %%
nhanes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7409 entries, 0 to 7408
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CaseOrder                       7409 non-null   Int64
#  1   Vitamin D blood level (nmol/L)  7409 non-null   Float64
#  2   Gender                          7409 non-null   object
#  3   Age                             7409 non-null   int32
#  4   Marital                         4532 non-null   object
#  5   Income                          6795 non-null   float64
#  6   Children                        7409 non-null   int32
# dtypes: Float64(1), Int64(1), float64(1), int32(2), object(2)
# memory usage: 419.7+ KB

# %%
# Our medical data has VitD level in ng/mL, NHANES has nmol/L - convert to nmol/L
med['Vitamin D blood level (nmol/L)'] = med.VitD_levels * 2.5
med.drop(axis=1, columns='VitD_levels', inplace=True)
med.head()
# Out:
#    CaseOrder State  Children  Age    Income   Marital  Gender ReAdmis  \
# 0          1    AL         1   53  86575.93  Divorced    Male      No
# 1          2    FL         3   51  46805.99   Married  Female      No
# 2          3    SD         3   53  14370.14   Widowed  Female      No
# 3          4    MN         0   78  39741.49   Married    Male      No
# 4          5    VA         1   22   1209.56   Widowed  Female      No
#
#    Vitamin D blood level (nmol/L)
# 0                       47.853664
# 1                       47.350881
# 2                       45.143768
# 3                       41.442145
# 4                       43.597673

# %%
allmed = med.merge(nhanes, how='outer', sort=True)
allmed
# Out:
#        CaseOrder State  Children  Age    Income        Marital  Gender  \
# 0              1    AL         1   53  86575.93       Divorced    Male
# 1              2    FL         3   51  46805.99        Married  Female
# 2              3    SD         3   53  14370.14        Widowed  Female
# 3              4    MN         0   78  39741.49        Married    Male
# 4              5    VA         1   22   1209.56        Widowed  Female
# ...          ...   ...       ...  ...       ...            ...     ...
# 17404     102952  <NA>         0   70   17500.0        Married  Female
# 17405     102953  <NA>         0   42   35000.0      Separated    Male
# 17406     102954  <NA>         4   41   70000.0  Never Married  Female
# 17407     102955  <NA>         1   14   60000.0            NaN  Female
# 17408     102956  <NA>         3   38   40000.0       Divorced    Male
#
#       ReAdmis  Vitamin D blood level (nmol/L)
# 0          No                       47.853664
# 1          No                       47.350881
# 2          No                       45.143768
# 3          No                       41.442145
# 4          No                       43.597673
# ...       ...                             ...
# 17404    <NA>                            82.7
# 17405    <NA>                            49.5
# 17406    <NA>                            50.5
# 17407    <NA>                            61.9
# 17408    <NA>                            58.9
#
# [17409 rows x 9 columns]

# %%
union = pd.concat([allmed, hosp])
union
# Out:
#        CaseOrder State  Children   Age    Income   Marital  Gender ReAdmis  \
# 0              1    AL         1    53  86575.93  Divorced    Male      No
# 1              2    FL         3    51  46805.99   Married  Female      No
# 2              3    SD         3    53  14370.14   Widowed  Female      No
# 3              4    MN         0    78  39741.49   Married    Male      No
# 4              5    VA         1    22   1209.56   Widowed  Female      No
# ...          ...   ...       ...   ...       ...       ...     ...     ...
# 18866       <NA>    TX      <NA>  <NA>      <NA>       NaN     NaN    <NA>
# 18867       <NA>    TX      <NA>  <NA>      <NA>       NaN     NaN    <NA>
# 18868       <NA>    TX      <NA>  <NA>      <NA>       NaN     NaN    <NA>
# 18869       <NA>    TX      <NA>  <NA>      <NA>       NaN     NaN    <NA>
# 18870       <NA>    TX      <NA>  <NA>      <NA>       NaN     NaN    <NA>
#
#        Vitamin D blood level (nmol/L)  Facility ID        Measure Name  \
# 0                           47.853664         <NA>                <NA>
# 1                           47.350881         <NA>                <NA>
# 2                           45.143768         <NA>                <NA>
# 3                           41.442145         <NA>                <NA>
# 4                           43.597673         <NA>                <NA>
# ...                               ...          ...                 ...
# 18866                            <NA>       670122    READM-30-HF-HRRP
# 18867                            <NA>       670122  READM-30-COPD-HRRP
# 18868                            <NA>       670122  READM-30-CABG-HRRP
# 18869                            <NA>       670122   READM-30-AMI-HRRP
# 18870                            <NA>       670124    READM-30-PN-HRRP
#
#        Predicted Readmission Rate
# 0                            <NA>
# 1                            <NA>
# 2                            <NA>
# 3                            <NA>
# 4                            <NA>
# ...                           ...
# 18866                     21.7744
# 18867                     20.1507
# 18868                     13.2609
# 18869                     14.1772
# 18870                     13.2679
#
# [30328 rows x 12 columns]

# %%
_ = union.to_csv('unified_data.csv')

# %%
union.head(10)
# Out:
#    CaseOrder State  Children  Age    Income        Marital  Gender ReAdmis  \
# 0          1    AL         1   53  86575.93       Divorced    Male      No
# 1          2    FL         3   51  46805.99        Married  Female      No
# 2          3    SD         3   53  14370.14        Widowed  Female      No
# 3          4    MN         0   78  39741.49        Married    Male      No
# 4          5    VA         1   22   1209.56        Widowed  Female      No
# 5          6    OK         3   76  81999.88  Never Married    Male      No
# 6          7    OH         0   50  10456.05  Never Married    Male      No
# 7          8    VA         7   40  38319.29       Divorced  Female      No
# 8          9    FL         0   48  55586.48        Widowed    Male      No
# 9         10    MN         2   78  38965.22  Never Married  Female      No
#
#    Vitamin D blood level (nmol/L)  Facility ID Measure Name  \
# 0                       47.853664         <NA>         <NA>
# 1                       47.350881         <NA>         <NA>
# 2                       45.143768         <NA>         <NA>
# 3                       41.442145         <NA>         <NA>
# 4                       43.597673         <NA>         <NA>
# 5                       49.031615         <NA>         <NA>
# 6                       36.879218         <NA>         <NA>
# 7                       49.221682         <NA>         <NA>
# 8                       49.133299         <NA>         <NA>
# 9                       45.560811         <NA>         <NA>
#
#    Predicted Readmission Rate
# 0                        <NA>
# 1                        <NA>
# 2                        <NA>
# 3                        <NA>
# 4                        <NA>
# 5                        <NA>
# 6                        <NA>
# 7                        <NA>
# 8                        <NA>
# 9                        <NA>
